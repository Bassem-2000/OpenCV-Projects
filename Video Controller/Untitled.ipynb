# %%
import pyautogui as p
import mediapipe as mp
import cv2
import numpy as np
import os

# %%
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)


mphands = mp.solutions.hands
hands = mphands.Hands(min_detection_confidence = 0.9)
mpdraw = mp.solutions.drawing_utils
video_path = r"C:\Users\user\Videos\2023-09-20 13-47-02.mkv"
os.startfile(video_path)

while True:
    ret, frame = cap.read()
    
    frame = cv2.flip(frame, 1)
    
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hands.process(rgb)
    
    lm_list = []
    
    if results.multi_hand_landmarks:
        for handlm in results.multi_hand_landmarks:
            for id, lm in enumerate(handlm.landmark):
                h, w, c = frame.shape
                x, y = int(lm.x * w), int(lm.y * h)
                lm_list.append([id, x, y])
            print(lm_list)
            mpdraw.draw_landmarks(frame, handlm, mphands.HAND_CONNECTIONS)
    
    if len(lm_list) != 0:
        
        finger1 = lm_list[8][2] < lm_list[6][2]
        finger2 = lm_list[12][2] < lm_list[10][2]
        finger3 = lm_list[16][2] < lm_list[14][2]
        finger4 = lm_list[20][2] < lm_list[18][2]
        
        if not (finger1 and finger2 and finger3 and finger4 ):
            p.press('space', interval=2)
            
              
    cv2.imshow('Video', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# [[0, 752, 447], [1, 708, 415], [2, 676, 366], [3, 654, 328], [4, 628, 305], [5, 739, 308], [6, 744, 259], [7, 746, 229], [8, 751, 203], [9, 778, 312], [10, 800, 258], [11, 815, 230], [12, 829, 205], [13, 808, 329], [14, 839, 280], [15, 858, 256], [16, 874, 235], [17, 833, 355], [18, 868, 324], [19, 889, 308], [20, 906, 292]]
# [[0, 750, 450], [1, 707, 418], [2, 676, 368], [3, 657, 329], [4, 636, 303], [5, 738, 309], [6, 744, 260], [7, 747, 231], [8, 751, 205], [9, 777, 312], [10, 800, 260], [11, 816, 230], [12, 831, 206], [13, 807, 328], [14, 837, 282], [15, 859, 257], [16, 877, 235], [17, 830, 355], [18, 863, 325], [19, 887, 309], [20, 907, 294]]
# [[0, 762, 431], [1, 717, 398], [2, 682, 351], [3, 664, 314], [4, 649, 282], [5, 743, 288], [6, 745, 237], [7, 747, 205], [8, 751, 177], [9, 780, 290], [10, 800, 235], [11, 815, 203], [12, 829, 175], [13, 810, 306], [14, 838, 259], [15, 856, 234], [16, 872, 212], [17, 834, 333], [18, 865, 302], [19, 887, 285], [20, 905, 268]]
# [[0, 763, 418], [1, 715, 386], [2, 683, 338], [3, 666, 298], [4, 650, 266], [5, 742, 276], [6, 742, 221], [7, 743, 186], [8, 746, 156], [9, 780, 278], [10, 798, 218], [11, 811, 182], [12, 823, 151], [13, 810, 294], [14, 836, 242], [15, 852, 212], [16, 866, 184], [17, 834, 320], [18, 865, 287], [19, 885, 265], [20, 902, 243]]
# [[0, 762, 419], [1, 715, 387], [2, 683, 339], [3, 667, 298], [4, 651, 266], [5, 743, 276], [6, 743, 219], [7, 743, 186], [8, 746, 156], [9, 781, 278], [10, 797, 218], [11, 810, 180], [12, 823, 148], [13, 811, 294], [14, 836, 242], [15, 855, 213], [16, 870, 187], [17, 835, 320], [18, 865, 286], [19, 886, 266], [20, 904, 247]]
ap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)

mphands = mp.solutions.hands
hands = mphands.Hands(min_detection_confidence=0.9)
mpdraw = mp.solutions.drawing_utils

video_path = r"C:\Users\user\Videos\2023-09-20 13-47-02.mkv"
webbrowser.open(video_path)
target_window = gw.getWindowsWithTitle('Media Player')

# Give some time for the browser to open and load the video

while True:
    ret, frame = cap.read()

    frame = cv2.flip(frame, 1)

    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hands.process(rgb)

    lm_list = []

    if results.multi_hand_landmarks:
        for handlm in results.multi_hand_landmarks:
            for id, lm in enumerate(handlm.landmark):
                h, w, c = frame.shape
                x, y = int(lm.x * w), int(lm.y * h)
                lm_list.append([id, x, y])
            mpdraw.draw_landmarks(frame, handlm, mphands.HAND_CONNECTIONS)

    if len(lm_list) != 0:

        finger1 = lm_list[8][2] > lm_list[6][2]
        finger2 = lm_list[12][2] > lm_list[10][2]
        finger3 = lm_list[16][2] > lm_list[14][2]
        finger4 = lm_list[20][2] > lm_list[18][2]

        if (finger1 and finger2 and finger3 and finger4):
            # target_window[0].activate()
            time.sleep(5)
            pyautogui.press('space')

    cv2.imshow('Video', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import pyautogui as p 
import time
import webbrowser
import pygetwindow as gw
import os

cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)

mphands = mp.solutions.hands
hands = mphands.Hands(min_detection_confidence=0.9)
mpdraw = mp.solutions.drawing_utils

video_path = r"C:\Users\user\Videos\2023-09-20 13-47-02.mkv"
webbrowser.open(video_path)


closed_hands_time = None
full_window = None
prev_time = None
forward_time = None
vol_up = None
vol_down = None
stop = None
def activate_window(window):
    target_window = gw.getWindowsWithTitle(f'{window}')
    if target_window:
        target_window[0].activate()
        
while True:
    ret, frame = cap.read()

    frame = cv2.flip(frame, 1)

    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hands.process(rgb)

    lm_list = []

    if results.multi_hand_landmarks:
        for handlm in results.multi_hand_landmarks:
            for id, lm in enumerate(handlm.landmark):
                h, w, c = frame.shape
                x, y = int(lm.x * w), int(lm.y * h)
                lm_list.append([id, x, y])
            mpdraw.draw_landmarks(frame, handlm, mphands.HAND_CONNECTIONS)
    
    finger1 = False
    finger2 = False
    finger3 = False
    finger4 = False

    if len(lm_list) != 0:
        
        finger0_xy_3 = lm_list[3][1:]
        
        finger1_up = lm_list[8][2] < lm_list[6][2]
        finger2_up = lm_list[12][2] < lm_list[10][2]
        
        finger0_xy = lm_list[4][1:]
        finger1_xy = lm_list[8][1:]
        finger4_xy = lm_list[20][1:]
       
        finger0 = lm_list[4][2] < lm_list[2][2]
        finger1 = lm_list[8][2] > lm_list[6][2]
        finger2 = lm_list[12][2] > lm_list[10][2]
        finger3 = lm_list[16][2] > lm_list[14][2]
        finger4 = lm_list[20][2] > lm_list[18][2]
        
         
            
        if (abs(finger0_xy[0] - finger1_xy[0]) <= 25) and (abs(finger0_xy[1] - finger1_xy[1]) <= 25):
            closed_hands_time = None
            prev_time = None
            forward_time = None
            
            if full_window is None:
                full_window = time.time()
            elif time.time() - full_window >= 0.5: 
                activate_window('Media Player')
                p.press('f11')
                full_window = time.time()      
                
        elif (finger0_xy[0] < finger4_xy[0]) and (finger0_xy[0] < finger0_xy_3[0]) and finger1 and finger2 and finger3 and finger4:
            closed_hands_time = None
            full_window = None
            forward_time = None
            
            if prev_time is None:
                prev_time = time.time()
            elif time.time() - prev_time >= 0.5: 
                activate_window('Media Player')
                p.hotkey('ctrl', 'left')
                prev_time = time.time() 
                
        elif (finger0_xy[0] > finger4_xy[0]) and (finger0_xy[0] > finger0_xy_3[0]) and finger1 and finger2 and finger3 and finger4:
            closed_hands_time = None
            full_window = None
            prev_time = None
            
            if forward_time is None:
                forward_time = time.time()
            elif time.time() - forward_time >= 0.5: 
                activate_window('Media Player')
                p.hotkey('ctrl', 'right')
                forward_time = time.time()   
                
        elif finger0 and finger1 and finger2 and finger3 and finger4:
            full_window = None
            prev_time = None
            forward_time = None

            if closed_hands_time is None:
                closed_hands_time = time.time()
            elif time.time() - closed_hands_time >= 0.5: 
                activate_window('Media Player')
                p.press('space')
                closed_hands_time = time.time()   
        elif finger1_up and finger2 and finger3 and finger4:
            full_window = None
            prev_time = None
            forward_time = None

            if vol_up is None:
                vol_up = time.time()
            elif time.time() - vol_up >= 0.5: 
                activate_window('Media Player')
                p.press('volumeup')
                vol_up = time.time()  
                
        elif finger1_up and finger2_up and finger3 and finger4:
            full_window = None
            prev_time = None
            forward_time = None

            if vol_down is None:
                vol_down = time.time()
            elif time.time() - vol_down >= 0.5: 
                activate_window('Media Player')
                p.press('volumedown')
                vol_down = time.time()  
        else:
            forward_time = None
            closed_hands_time = None
            full_window = None
            prev_time = None
        

    cv2.imshow('Video', frame)
    if not (finger1) and not (finger4) and finger2 and finger3:
        if stop is None:
                stop = time.time()
        elif time.time() - stop >= 0.5: 
            activate_window('Media Player')
            p.hotkey('alt', 'f4')
            break  
    cv2.waitKey(1)

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import pyautogui as p 
import time
import webbrowser
import pygetwindow as gw

# Set the video capture properties
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 120)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 120)

# Initialize MediaPipe Hands
mphands = mp.solutions.hands
hands = mphands.Hands(min_detection_confidence=0.9)
mpdraw = mp.solutions.drawing_utils

# Path to the video you want to open
video_path = r"C:\Users\user\Videos\2023-09-20 13-47-02.mkv"

# Open the video in the default web browser
webbrowser.open(video_path)

# Initialize variables for hand gestures
closed_hands_time = None
full_window = None
prev_time = None
forward_time = None
vol_up = None
vol_down = None
stop = None

# Function to activate a specific window
def activate_window(window_title):
    target_window = gw.getWindowsWithTitle(window_title)
    if target_window:
        target_window[0].activate()

while True:
    ret, frame = cap.read()

    # Flip the frame horizontally for a mirrored view
    frame = cv2.flip(frame, 1)

    # Convert the frame to RGB format for Mediapipe
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hands.process(rgb)

    lm_list = []

    if results.multi_hand_landmarks:
        for handlm in results.multi_hand_landmarks:
            for id, lm in enumerate(handlm.landmark):
                h, w, c = frame.shape
                x, y = int(lm.x * w), int(lm.y * h)
                lm_list.append([id, x, y])
            mpdraw.draw_landmarks(frame, handlm, mphands.HAND_CONNECTIONS)

    # Detect hand gestures
    finger1 = False
    finger2 = False
    finger3 = False
    finger4 = False

    if len(lm_list) != 0:
        finger0_xy_3 = lm_list[3][1:]
        finger1_up = lm_list[8][2] < lm_list[6][2]
        finger2_up = lm_list[12][2] < lm_list[10][2]
        finger0_xy = lm_list[4][1:]
        finger1_xy = lm_list[8][1:]
        finger4_xy = lm_list[20][1:]

        finger0 = lm_list[4][2] < lm_list[2][2]
        finger1 = lm_list[8][2] > lm_list[6][2]
        finger2 = lm_list[12][2] > lm_list[10][2]
        finger3 = lm_list[16][2] > lm_list[14][2]
        finger4 = lm_list[20][2] > lm_list[18][2]
        
        # Check for the 'F11' gesture
        if (abs(finger0_xy[0] - finger1_xy[0]) <= 25) and (abs(finger0_xy[1] - finger1_xy[1]) <= 25):
            forward_time = None
            closed_hands_time = None
            prev_time = None
            vol_down =  None
            vol_up = None

            if full_window is None:
                full_window = time.time()
            elif time.time() - full_window >= 0.5: 
                activate_window('Media Player')
                p.press('f11')
                full_window = time.time()      
        
        # Check for the 'Ctrl+Left' gesture
        elif (finger0_xy[0] < finger4_xy[0]) and (finger0_xy[0] < finger0_xy_3[0]) and finger1 and finger2 and finger3 and finger4:
            forward_time = None
            closed_hands_time = None
            full_window = None
            vol_down =  None
            vol_up = None

            if prev_time is None:
                prev_time = time.time()
            elif time.time() - prev_time >= 0.5: 
                activate_window('Media Player')
                p.hotkey('ctrl', 'left')
                prev_time = time.time() 
        
        # Check for the 'Ctrl+Right' gesture
        elif (finger0_xy[0] > finger4_xy[0]) and (finger0_xy[0] > finger0_xy_3[0]) and finger1 and finger2 and finger3 and finger4:
            closed_hands_time = None
            full_window = None
            prev_time = None
            vol_down =  None
            vol_up = None

            if forward_time is None:
                forward_time = time.time()
            elif time.time() - forward_time >= 0.5: 
                activate_window('Media Player')
                p.hotkey('ctrl', 'right')
                forward_time = time.time()   
        
        # Check for the 'Space' gesture
        elif finger0 and finger1 and finger2 and finger3 and finger4:
            full_window = None
            prev_time = None
            vol_down =  None
            vol_up = None
            forward_time = None

            if closed_hands_time is None:
                closed_hands_time = time.time()
            elif time.time() - closed_hands_time >= 0.5: 
                activate_window('Media Player')
                p.press('space')
                closed_hands_time = time.time()   
        
        # Check for the 'Volume Up' gesture
        elif finger1_up and finger2 and finger3 and finger4:
            forward_time = None
            closed_hands_time = None
            full_window = None
            prev_time = None
            vol_down =  None

            if vol_up is None:
                vol_up = time.time()
            elif time.time() - vol_up >= 0.5: 
                activate_window('Media Player')
                p.press('volumeup')
                vol_up = time.time()  
        
        # Check for the 'Volume Down' gesture
        elif finger1_up and finger2_up and finger3 and finger4:
            forward_time = None
            closed_hands_time = None
            full_window = None
            prev_time = None
            vol_up = None

            if vol_down is None:
                vol_down = time.time()
            elif time.time() - vol_down >= 0.5: 
                activate_window('Media Player')
                p.press('volumedown')
                vol_down = time.time()  
        else:
            forward_time = None
            closed_hands_time = None
            full_window = None
            prev_time = None
            vol_down =  None
            vol_up = None

    cv2.imshow('Video', frame)
    
    # Detect the gesture to stop the video
    if not (finger1) and not (finger4) and finger2 and finger3:
        if stop is None:
            stop = time.time()
        elif time.time() - stop >= 0.5: 
            activate_window('Media Player')
            p.hotkey('alt', 'f4')
            break  
    cv2.waitKey(1)

# Release the video capture and close all windows
cap.release()
cv2.destroyAllWindows()
